# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Mental_health_responses.csv')

# %%
len(df)
# Out:
# 1260

# %%
len(df.columns)
# Out:
# 27

# %%
df = df.rename(columns={'Have you sought treatment for a mental health condition?': 'treatment', \
                        'Do you think that discussing a mental health issue with your employer would have negative consequences?': 'mental_health_consequence',\
                       'Do you think that discussing a physical health issue with your employer would have negative consequences?': 'phys_health_consequence'})

# %%
df.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'Country',
#        'If you live in the United States, which state or territory do you live in?',
#        'Are you self-employed?',
#        'Do you have a family history of mental illness?', 'treatment',
#        'If you have a mental health condition, do you feel that it interferes with your work?',
#        'How many employees does your company or organization have?',
#        'Do you work remotely (outside of an office) at least 50% of the time?',
#        'Is your employer primarily a tech company/organization?',
#        'Does your employer provide mental health benefits?',
#        'Do you know the options for mental health care your employer provides?',
#        'Has your employer ever discussed mental health as part of an employee wellness program?',
#        'Does your employer provide resources to learn more about mental health issues and how to seek help?',
# ...

# %%
df = df[df['Age'] > 0]

# %%
df = df[df['Age'] < 100]

# %%
len(df)
# Out:
# 1255

# %%
df['Age'].min()
# Out:
# 5

# %%
df['Age'].max()
# Out:
# 72

# %%
df_treat_y = df[df['treatment'] == 'Yes']

# %%
plt.hist(df_treat_y['Age'], bins=4)
# Out:
# (array([ 53., 475.,  96.,   9.]),
#  array([ 8., 24., 40., 56., 72.]),
#  <a list of 4 Patch objects>)

# %%
df_treat_n = df[df['treatment'] == 'No']

# %%
plt.hist(df_treat_n['Age'], bins=4)
# Out:
# (array([ 11., 438., 159.,  14.]),
#  array([ 5., 20., 35., 50., 65.]),
#  <a list of 4 Patch objects>)

# %%
df
# Out:
#                 Timestamp  Age  \
# 0      8/27/2014 11:29:31   37
# 1      8/27/2014 11:29:37   44
# 2      8/27/2014 11:29:44   32
# 3      8/27/2014 11:29:46   31
# 4      8/27/2014 11:30:22   31
# 5      8/27/2014 11:31:22   33
# 6      8/27/2014 11:31:50   35
# 7      8/27/2014 11:32:05   39
# 8      8/27/2014 11:32:39   42
# 9      8/27/2014 11:32:44   23
# 10     8/27/2014 11:32:45   31
# 11     8/27/2014 11:32:50   29
# 12     8/27/2014 11:33:23   42
# 13     8/27/2014 11:33:27   36
# 14     8/27/2014 11:33:57   27
# 15     8/27/2014 11:34:01   29
# 16     8/27/2014 11:34:20   23
# 17     8/27/2014 11:34:38   32
# 18     8/27/2014 11:34:54   46
# 19     8/27/2014 11:35:08   36
# 20     8/27/2014 11:35:13   29
# 21     8/27/2014 11:35:24   31
# 22     8/27/2014 11:35:48   46
# 23     8/27/2014 11:36:24   41
# 24     8/27/2014 11:36:48   33
# 25     8/27/2014 11:37:09   35
# 26     8/27/2014 11:37:23   33
# 27     8/27/2014 11:38:00   35
# 28     8/27/2014 11:38:13   34
# ...

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'M', 'Male', 'male', 'female', 'm', 'Male-ish', 'maile',
#        'Trans-female', 'Cis Female', 'F', 'something kinda male?',
#        'Cis Male', 'Woman', 'f', 'Mal', 'Male (CIS)', 'queer/she/they',
#        'non-binary', 'Femake', 'woman', 'Make', 'Nah', 'Enby', 'fluid',
#        'Genderqueer', 'Female ', 'Androgyne', 'Agender',
#        'cis-female/femme', 'Guy (-ish) ^_^', 'male leaning androgynous',
#        'Male ', 'Man', 'Trans woman', 'msle', 'Neuter', 'Female (trans)',
#        'queer', 'Female (cis)', 'Mail', 'cis male', 'A little about you',
#        'Malr', 'femail', 'Cis Man',
#        'ostensibly male, unsure what that really means'], dtype=object)

# %%
df['Country'].unique()
# Out:
# array(['United States', 'Canada', 'United Kingdom', 'Bulgaria', 'France',
#        'Portugal', 'Netherlands', 'Switzerland', 'Poland', 'Australia',
#        'Germany', 'Russia', 'Mexico', 'Brazil', 'Slovenia', 'Costa Rica',
#        'Austria', 'Ireland', 'India', 'South Africa', 'Italy', 'Sweden',
#        'Colombia', 'Latvia', 'Romania', 'Belgium', 'New Zealand', 'Spain',
#        'Finland', 'Uruguay', 'Israel', 'Bosnia and Herzegovina',
#        'Hungary', 'Singapore', 'Japan', 'Nigeria', 'Croatia', 'Norway',
#        'Thailand', 'Denmark', 'Bahamas, The', 'Greece', 'Moldova',
#        'Georgia', 'China', 'Czech Republic', 'Philippines'], dtype=object)

# %%
df_country_treat_y = df[df['treatment'] == 'Yes']

# %%
type(df_country_treat_y)
# Out:
# pandas.core.frame.DataFrame

# %%
d = {}
for i,row in df_country_treat_y.iterrows():
    c = row['Country']
#     print(row['Country'])
    if c in d:
        d[c]+=1
    else:
        d[c] = 1

# %%
plt.bar(d.keys(), d.values())
# Out:
# <BarContainer object of 27 artists>

# %%
df_country_treat_n = df[df['treatment'] == 'No']
d = {}
for i,row in df_country_treat_y.iterrows():
    c = row['Country']
#     print(row['Country'])
    if c in d:
        d[c]+=1
    else:
        d[c] = 1
plt.bar(d.keys(), d.values())
# Out:
# <BarContainer object of 27 artists>

# %%
df_gender_treat_n = df[df['treatment'] == 'Yes']
d = {}
for i,row in df_country_treat_y.iterrows():
    c = row['Gender']
#     print(row['Country'])
    if c in d:
        d[c]+=1
    else:
        d[c] = 1
plt.bar(d.keys(), d.values())
# Out:
# <BarContainer object of 33 artists>

# %%
df_gender_treat_n = df[df['treatment'] == 'No']
d = {}
for i,row in df_country_treat_y.iterrows():
    c = row['Gender']
#     print(row['Country'])
    if c in d:
        d[c]+=1
    else:
        d[c] = 1
plt.bar(d.keys(), d.values())
# Out:
# <BarContainer object of 33 artists>

# %%
df_age_mental_health_y = df[df['mental_health_consequence'] == 'Yes']
plt.hist(df_age_mental_health_y['Age'], bins=4)
# Out:
# (array([ 14., 169.,  95.,  12.]),
#  array([ 8.  , 21.25, 34.5 , 47.75, 61.  ]),
#  <a list of 4 Patch objects>)

# %%
df_age_mental_health_n = df[df['mental_health_consequence'] == 'No']
plt.hist(df_age_mental_health_n['Age'], bins=4)
# Out:
# (array([  5., 294., 174.,  16.]),
#  array([ 5.  , 18.75, 32.5 , 46.25, 60.  ]),
#  <a list of 4 Patch objects>)

# %%
df_gender_mental_health_y = df[df['mental_health_consequence'] == 'Yes']
d = {}
for i,row in df_gender_mental_health_y.iterrows():
    c = row['Gender']
#     print(row['Country'])
    if c in d:
        d[c]+=1
    else:
        d[c] = 1
plt.bar(d.keys(), d.values())
# Out:
# <BarContainer object of 23 artists>

# %%
df_gender_mental_health_n = df[df['mental_health_consequence'] == 'No']
d = {}
for i,row in df_gender_mental_health_n.iterrows():
    c = row['Gender']
#     print(row['Country'])
    if c in d:
        d[c]+=1
    else:
        d[c] = 1
plt.bar(d.keys(), d.values())
# Out:
# <BarContainer object of 20 artists>

# %%
df_country_mental_health_y = df[df['mental_health_consequence'] == 'Yes']
d = {}
for i,row in df_country_mental_health_y.iterrows():
    c = row['Country']
#     print(row['Country'])
    if c in d:
        d[c]+=1
    else:
        d[c] = 1
plt.bar(d.keys(), d.values())
# Out:
# <BarContainer object of 30 artists>

# %%
df_country_mental_health_y = df[df['mental_health_consequence'] == 'Yes']
d = {}
for i,row in df_gender_mental_health_y.iterrows():
    c = row['Country']
#     print(row['Country'])
    if c in d:
        d[c]+=1
    else:
        d[c] = 1
plt.bar(d.keys(), d.values())
# Out:
# <BarContainer object of 30 artists>

# %%
df_age_physical_health_y = df[df['phys_health_consequence'] == 'Yes']
plt.hist(df_age_physical_health_y['Age'], bins=4)
# Out:
# (array([ 1., 15., 34.,  9.]),
#  array([ 8.  , 18.75, 29.5 , 40.25, 51.  ]),
#  <a list of 4 Patch objects>)

# %%
df_age_physical_health_n = df[df['phys_health_consequence'] == 'No']
plt.hist(df_age_physical_health_n['Age'], bins=4)
# Out:
# (array([ 13., 648., 244.,  18.]),
#  array([ 5., 20., 35., 50., 65.]),
#  <a list of 4 Patch objects>)

# %%
df_gender_physical_health_y = df[df['phys_health_consequence'] == 'Yes']
d = {}
for i,row in df_gender_physical_health_y.iterrows():
    c = row['Gender']
#     print(row['Country'])
    if c in d:
        d[c]+=1
    else:
        d[c] = 1
plt.bar(d.keys(), d.values())
# Out:
# <BarContainer object of 9 artists>

# %%
df_gender_physical_health_n = df[df['phys_health_consequence'] == 'No']
d = {}
for i,row in df_gender_physical_health_n.iterrows():
    c = row['Gender']
#     print(row['Country'])
    if c in d:
        d[c]+=1
    else:
        d[c] = 1
plt.bar(d.keys(), d.values())
# Out:
# <BarContainer object of 33 artists>

# %%
df_country_physical_health_y = df[df['phys_health_consequence'] == 'Yes']
d = {}
for i,row in df_country_physical_health_y.iterrows():
    c = row['Country']
#     print(row['Country'])
    if c in d:
        d[c]+=1
    else:
        d[c] = 1
plt.bar(d.keys(), d.values())
# Out:
# <BarContainer object of 17 artists>

# %%
df_country_physical_health_n= df[df['phys_health_consequence'] == 'No']
d = {}
for i,row in df_country_physical_health_n.iterrows():
    c = row['Country']
#     print(row['Country'])
    if c in d:
        d[c]+=1
    else:
        d[c] = 1
plt.bar(d.keys(), d.values())
# Out:
# <BarContainer object of 37 artists>
